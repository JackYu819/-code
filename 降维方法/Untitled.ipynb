# %%
import os
import sys

# %%
sys.path.append('/Users/yuxiangyu/Desktop/毕业论文code')

# %%
from DataAnalysis import DataAnalysis as DA

# %%
stat_db = DA()

# %%
data_sets_list = stat_db.datasets

# %%
data_sets_list
# Out:
# ['/Users/yuxiangyu/Documents/论文材料/实验室/Iris/iris.csv',
#  '/Users/yuxiangyu/Documents/论文材料/实验室/Winequality/new-winequality-white.txt',
#  '/Users/yuxiangyu/Documents/论文材料/实验室/Winequality/new-winequality-red.txt',
#  '/Users/yuxiangyu/Documents/论文材料/实验室/Glass/new1-new-glass.txt',
#  '/Users/yuxiangyu/Documents/论文材料/实验室/Glass/new1-new-glass.txt',
#  '/Users/yuxiangyu/Documents/论文材料/实验室/seeds/seeds_dataset.txt',
#  '/Users/yuxiangyu/Documents/论文材料/实验室/breast_cancer/new-breast-cancer-wisconsin.txt',
#  '/Users/yuxiangyu/Documents/论文材料/实验室/Wine/new-win.txt',
#  '/Users/yuxiangyu/Documents/论文材料/实验室/balance_scale/new-balance-scale.txt',
#  '/Users/yuxiangyu/Documents/论文材料/实验室/segmentation/new-segmentation.txt']

# %%
stat_db.open_csv(data_sets_list[0])
# Out:
#      col_1  col_2  col_3  col_4            label
# 0      6.7    3.3    5.7    2.1   Iris-virginica
# 1      6.4    3.2    5.3    2.3   Iris-virginica
# 2      4.4    3.0    1.3    0.2      Iris-setosa
# 3      5.0    3.5    1.3    0.3      Iris-setosa
# 4      5.0    3.4    1.6    0.4      Iris-setosa
# 5      5.4    3.9    1.3    0.4      Iris-setosa
# 6      4.8    3.1    1.6    0.2      Iris-setosa
# 7      5.8    2.7    3.9    1.2  Iris-versicolor
# 8      7.7    2.8    6.7    2.0   Iris-virginica
# 9      4.3    3.0    1.1    0.1      Iris-setosa
# 10     5.0    3.3    1.4    0.2      Iris-setosa
# 11     6.6    2.9    4.6    1.3  Iris-versicolor
# 12     7.7    2.6    6.9    2.3   Iris-virginica
# 13     5.2    2.7    3.9    1.4  Iris-versicolor
# 14     4.5    2.3    1.3    0.3      Iris-setosa
# 15     5.7    2.9    4.2    1.3  Iris-versicolor
# 16     5.5    2.5    4.0    1.3  Iris-versicolor
# 17     5.1    3.7    1.5    0.4      Iris-setosa
# ...
